# %%
import pickle
from matplotlib import pyplot as plt
import numpy as np

# %%
with open('../stats_Adam.pkl','rb') as f:
    l_loss, c_loss, itr = pickle.load(f)

# %%
l_loss = np.asarray(l_loss)
c_loss = np.asarray(c_loss)
itr = np.asarray(itr)

# %%
plt.plot(itr[7::],l_loss[7::]+c_loss[7::])
plt.xlabel('Iterations')
plt.ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')

# %%
c_loss
# Out:
# array([ 22.99439179, 254.05477977,  38.46714109, ...,   4.82799396,
#          4.8361035 ,   4.47804302])
