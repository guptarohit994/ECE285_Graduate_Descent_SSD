# %%
import pickle
from matplotlib import pyplot as plt
import numpy as np

# %%
with open('../stats_lr_+0.01.pkl','rb') as f:
    l_loss, c_loss, itr = pickle.load(f)

# %%
l_loss = np.asarray(l_loss)
c_loss = np.asarray(c_loss)
itr = np.asarray(itr)

# %% [markdown]
# ### nan after second iteration

# %%
plt.plot(itr,l_loss+c_loss)
plt.xlabel('Iterations')
plt.ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')

# %%
with open('../stats_lr_+1e-05.pkl','rb') as f:
    l_loss, c_loss, itr = pickle.load(f)

# %%
l_loss = np.asarray(l_loss)
c_loss = np.asarray(c_loss)
itr = np.asarray(itr)

# %% [markdown]
# ### nan after 5th iteration

# %%
plt.plot(itr,l_loss+c_loss)
plt.xlabel('Iterations')
plt.ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')

# %%
with open('../stats_lr_+0.0001.pkl','rb') as f:
    l_loss, c_loss, itr = pickle.load(f)

# %%
l_loss = np.asarray(l_loss)
c_loss = np.asarray(c_loss)
itr = np.asarray(itr)

# %%
plt.plot(itr,l_loss+c_loss)
plt.xlabel('Iterations')
plt.ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')

# %%
with open('../stats_lr_+0.1.pkl','rb') as f:
    l_loss, c_loss, itr = pickle.load(f)

# %%
l_loss = np.asarray(l_loss)
c_loss = np.asarray(c_loss)
itr = np.asarray(itr)

# %% [markdown]
# ### nan after 1st iteration

# %%
plt.plot(itr,l_loss+c_loss)
plt.xlabel('Iterations')
plt.ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')
